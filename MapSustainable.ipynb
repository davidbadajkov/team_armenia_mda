# %%
#!pip install geopandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas

# %%
df = pd.read_csv('https://s3grouparmenia.s3.eu-central-1.amazonaws.com/Transcripts_with_sentiment_topic')
df.head()
# Out:
#    Unnamed: 0  Year_x  Session_x Country_x  ...    neg    neu    pos  compound
# 0           0    2018         73       BRB  ...  0.113  0.687  0.200    0.9979
# 1           1    2018         73       IND  ...  0.178  0.606  0.216    0.9825
# 2           2    2018         73       ARG  ...  0.139  0.593  0.268    0.9975
# 3           3    2018         73       JOR  ...  0.181  0.527  0.292    0.9980
# 4           4    2018         73       SWE  ...  0.135  0.571  0.293    0.9995
#
# [5 rows x 13 columns]

# %%
df['Year_x'].max()
# Out:
# 2018

# %%
#filter years between 1990-2019

df2 = df[df['Year_x'] >= int('1990')]
df2['Year_x'].min()
# Out:
# 1990

# %%
sus_df = df2[df2['topic_name'] == 'sustainable development']
len(sus_df)
# Out:
# 576

# %%
group_df = sus_df.groupby(["Country_x"])[sus_df.columns[6]].count()
group_df = group_df.reset_index()
group_df.rename(columns={'topic_name':'count'}, inplace=True)
group_df
# Out:
#     Country_x  count
# 0         ALB      1
# 1         AND     18
# 2         ARG      7
# 3         ARM      3
# 4         ATG      1
# ..        ...    ...
# 120       VEN     19
# 121       VNM      1
# 122       VUT      2
# 123       ZAF      6
# 124       ZWE      2
#
# [125 rows x 2 columns]

# %%
sdi = pd.read_excel('https://s3grouparmenia.s3.eu-central-1.amazonaws.com/SDI.xlsx')
sdi.head()
# Out:
#    iso              country   1990   1991  ...   2016   2017   2018   2019
# 0  AFG          Afghanistan  0.325  0.331  ...  0.541  0.545  0.549  0.551
# 1  ALB              Albania  0.699  0.680  ...  0.821  0.821  0.823  0.826
# 2  DZA              Algeria  0.616  0.621  ...  0.798  0.800  0.801  0.803
# 3  AGO               Angola    NaN    NaN  ...  0.622  0.627  0.627  0.626
# 4  ATG  Antigua and Barbuda    NaN    NaN  ...  0.617  0.616  0.619  0.622
#
# [5 rows x 32 columns]

# %%
sdi2 = pd.melt(frame=sdi ,id_vars=["iso", "country"],var_name="Year_x",value_name="SDI")
sdi_l = sdi2[sdi2['Year_x'] != '2019']
#sdi_l['Year_x']=sdi_l['Year_x'].astype(int)
sdi_l['Year_x'].max()
# Out:
# '2018'

# %%
group_sdi = sdi_l.groupby(["iso"])[sdi_l.columns[3]].mean()
group_sdi = group_sdi.reset_index()
group_sdi.rename(columns={'SDI':'SDI_mean'}, inplace=True)
group_sdi
# Out:
#      iso  SDI_mean
# 0    AFG  0.437552
# 1    AGO  0.537050
# 2    ALB  0.750828
# 3    ARE  0.137966
# 4    ARG  0.796552
# ..   ...       ...
# 160  WSM  0.717931
# 161  YEM  0.495172
# 162  ZAF  0.654759
# 163  ZMB  0.514966
# 164  ZWE  0.506966
#
# [165 rows x 2 columns]

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

cities = geopandas.read_file(geopandas.datasets.get_path('naturalearth_cities'))

str(world['name']).lower()
world
#world.plot()
# Out:
#        pop_est  ...                                           geometry
# 0       920938  ...  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1     53950935  ...  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2       603253  ...  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3     35623680  ...  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    326625791  ...  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..         ...  ...                                                ...
# 172    7111024  ...  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173     642550  ...  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174    1895250  ...  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175    1218208  ...  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176   13026129  ...  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [177 rows x 6 columns]

# %%
#map data merges with SDI data
merge_df1 = pd.merge(world, group_sdi,how = 'left', left_on=["iso_a3"], right_on=["iso"]).drop(columns='iso')

merge_df1
# Out:
#        pop_est  ...  SDI_mean
# 0       920938  ...  0.756103
# 1     53950935  ...  0.466517
# 2       603253  ...       NaN
# 3     35623680  ...  0.288793
# 4    326625791  ...  0.231276
# ..         ...  ...       ...
# 172    7111024  ...  0.548571
# 173     642550  ...       NaN
# 174    1895250  ...       NaN
# 175    1218208  ...  0.731931
# 176   13026129  ...       NaN
#
# [177 rows x 7 columns]

# %%
#merge with topic data
map_df = pd.merge(merge_df1, group_df,how = 'left', left_on=["iso_a3"], right_on=["Country_x"]).drop(columns="Country_x")
#normalize count to 0-1 range
map_df["normalized"] = (map_df["count"]-1) / map_df["count"].max()
#implement index(change the name?)
map_df['index'] = map_df['normalized'] / map_df["SDI_mean"]

map_df
# Out:
#        pop_est      continent  ... normalized     index
# 0       920938        Oceania  ...        NaN       NaN
# 1     53950935         Africa  ...        NaN       NaN
# 2       603253         Africa  ...        NaN       NaN
# 3     35623680  North America  ...   0.346154  1.198622
# 4    326625791  North America  ...   0.961538  4.157539
# ..         ...            ...  ...        ...       ...
# 172    7111024         Europe  ...   0.038462  0.070112
# 173     642550         Europe  ...        NaN       NaN
# 174    1895250         Europe  ...        NaN       NaN
# 175    1218208  North America  ...        NaN       NaN
# 176   13026129         Africa  ...        NaN       NaN
#
# [177 rows x 10 columns]

# %%
len(map_df[map_df.isna().any(axis=1)])
# Out:
# 79

# %%
#coordination from speech to implement in improving sustainable environment
fig, ax = plt.subplots(1, figsize=(30, 10))
#map_df.plot(column = 'index', legend = True,ax=ax)
map_df.plot(column='index', ax=ax, legend=True, legend_kwds={'label': "Index by Country"},
            missing_kwds={ "color": "lightgrey","label": "Missing values"})

# %%
#Top 5 worst coordination from speech to implement in improving sustainable environment
map_df[['name','count','SDI_mean','index']].sort_values(by=['index'],ascending=False).head(5)
# Out:
#                          name  count  SDI_mean     index
# 4    United States of America   26.0  0.231276  4.157539
# 3                      Canada   10.0  0.288793  1.198622
# 143            United Kingdom   15.0  0.481414  1.118500
# 40                  Venezuela   19.0  0.736345  0.940195
# 76                     Israel   12.0  0.533276  0.793355

# %%
#Top 20 best coordination from speech to implement in improving sustainable environment
map_df[['name','count','SDI_mean','index']].sort_values(by=['index'],ascending=False).dropna().tail(50)
# Out:
#                 name  count  SDI_mean     index
# 83            Jordan    4.0  0.755621  0.152702
# 85             Qatar    2.0  0.255276  0.150667
# 102         Pakistan    3.0  0.512690  0.150038
# 33            Panama    4.0  0.790103  0.146037
# 150         Slovenia    3.0  0.596179  0.129027
# 18            Russia    3.0  0.723607  0.106305
# 171        Macedonia    3.0  0.724842  0.106124
# 17    Dominican Rep.    3.0  0.725276  0.106060
# 109          Armenia    3.0  0.754893  0.101899
# 11   Dem. Rep. Congo    2.0  0.425414  0.090410
# 127      Switzerland    2.0  0.430931  0.089252
# 155            Japan    2.0  0.440414  0.087330
# 80            Gambia    2.0  0.454483  0.084627
# 154          Eritrea    2.0  0.464714  0.082764
# 120          Estonia    2.0  0.470862  0.081683
# 48          Zimbabwe    2.0  0.506966  0.075866
# 90          Cambodia    2.0  0.512690  0.075019
# 172           Serbia    2.0  0.548571  0.070112
# 132            Spain    2.0  0.554483  0.069365
# 35         Nicaragua    2.0  0.634655  0.060602
# 89           Vanuatu    2.0  0.635714  0.060501
# 6         Uzbekistan    2.0  0.700000  0.054945
# 27            Mexico    2.0  0.750552  0.051244
# 50           Namibia    1.0  0.616621  0.000000
# 71            Malawi    1.0  0.431724  0.000000
# 67             Congo    1.0  0.542655  0.000000
# 61            Guinea    1.0  0.403000  0.000000
# 57          Cameroon    1.0  0.516276  0.000000
# 122         Bulgaria    1.0  0.760655  0.000000
# 46           Jamaica    1.0  0.732414  0.000000
# 81           Tunisia    1.0  0.717069  0.000000
# 162          Morocco    1.0  0.610552  0.000000
# 164            Libya    1.0  0.760724  0.000000
# 5         Kazakhstan    1.0  0.551214  0.000000
# 77           Lebanon    1.0  0.715786  0.000000
# 87              Iraq    1.0  0.643379  0.000000
# 124           Turkey    1.0  0.678517  0.000000
# 145       Azerbaijan    1.0  0.732792  0.000000
# 94           Vietnam    1.0  0.649655  0.000000
# 97          Mongolia    1.0  0.665966  0.000000
# 99        Bangladesh    1.0  0.546000  0.000000
# 105       Kyrgyzstan    1.0  0.691643  0.000000
# 136      New Zealand    1.0  0.594379  0.000000
# 106     Turkmenistan    1.0  0.320000  0.000000
# 110           Sweden    1.0  0.507931  0.000000
# 112          Ukraine    1.0  0.749643  0.000000
# 114          Austria    1.0  0.409655  0.000000
# 119           Latvia    1.0  0.706552  0.000000
# 125          Albania    1.0  0.750828  0.000000
# 100           Bhutan    1.0  0.624643  0.000000

# %% [markdown]
# Index = normalized/SDI_mean
#
# normalized: (normalized)counts on topics of sustainable environment by countries in 1990-2018
#
# SDI: means of sustainable development index from 1990 to 2018
#
# Smaller values of index indicate better coordination from speech to implement in improving sustainable environment and climate change problems.

# %%
#who like to make speeches about sustainable enviroenment
fig, ax = plt.subplots(1, figsize=(30, 10))
map_df.plot(column='count', ax=ax, legend=True, legend_kwds={'label': "speeches on sustainable enviroenment by Country"},
            missing_kwds={ "color": "lightgrey","label": "Missing values"})

# %%
#Top 20 countries like to make speeches about sustainable enviroenment
map_df[['name','count','SDI_mean','index']].sort_values(by=['count'],ascending=False).head(20)
# Out:
#                          name  count  SDI_mean     index
# 4    United States of America   26.0  0.231276  4.157539
# 40                  Venezuela   19.0  0.736345  0.940195
# 143            United Kingdom   15.0  0.481414  1.118500
# 32                   Colombia   13.0  0.736103  0.627002
# 30                    Bolivia   12.0  0.686621  0.616173
# 29                     Brazil   12.0  0.728034  0.581122
# 76                     Israel   12.0  0.533276  0.793355
# 147               Philippines   12.0  0.699586  0.604753
# 111                   Belarus   12.0       NaN       NaN
# 148                  Malaysia   11.0  0.638276  0.602585
# 47                       Cuba   11.0  0.767034  0.501432
# 3                      Canada   10.0  0.288793  1.198622
# 107                      Iran   10.0  0.648414  0.533847
# 113                    Poland   10.0  0.637138  0.543295
# 34                 Costa Rica   10.0  0.792000  0.437063
# 36                   Honduras    9.0  0.625172  0.492172
# 44                    Ecuador    9.0  0.746759  0.412037
# 28                    Uruguay    9.0  0.689690  0.446132
# 149                    Brunei    9.0  0.531828  0.578557
# 121                   Germany    9.0  0.546034  0.563503

# %%
#who have the highest average SDI between 1990 and 2018
fig, ax = plt.subplots(1, figsize=(30, 10))
map_df.plot(column='SDI_mean', ax=ax, legend=True, legend_kwds={'label': "Average SDI between 1990 and 2018 by Country"},
            missing_kwds={ "color": "lightgrey","label": "Missing values"})

# %%
#Top 20 highest average SDI between 1990 and 2018
map_df[['name','count','SDI_mean','index']].sort_values(by=['SDI_mean'],ascending=False).head(20)
# Out:
#            name  count  SDI_mean     index
# 9     Argentina    7.0  0.796552  0.289710
# 146     Georgia    9.0  0.792684  0.388165
# 34   Costa Rica   10.0  0.792000  0.437063
# 33       Panama    4.0  0.790103  0.146037
# 10        Chile    6.0  0.769034  0.250064
# 138   Sri Lanka    6.0  0.767379  0.250603
# 47         Cuba   11.0  0.767034  0.501432
# 164       Libya    1.0  0.760724  0.000000
# 122    Bulgaria    1.0  0.760655  0.000000
# 115     Hungary    6.0  0.756172  0.254317
# 0          Fiji    NaN  0.756103       NaN
# 83       Jordan    4.0  0.755621  0.152702
# 109     Armenia    3.0  0.754893  0.101899
# 125     Albania    1.0  0.750828  0.000000
# 27       Mexico    2.0  0.750552  0.051244
# 112     Ukraine    1.0  0.749643  0.000000
# 44      Ecuador    9.0  0.746759  0.412037
# 117     Romania    4.0  0.746345  0.154600
# 31         Peru    6.0  0.743828  0.258538
# 116     Moldova    NaN  0.740357       NaN

# %% [markdown]
# Calculation of SDI
#
# https://www.sustainabledevelopmentindex.org/methods
